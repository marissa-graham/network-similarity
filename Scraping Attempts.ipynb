# %%
import smtplib
import gspread
import csv
from oauth2client.service_account import ServiceAccountCredentials
import importlib
import paperdatabase

# %%
importlib.reload(paperdatabase)
sheet = paperdatabase.get_sheet()
print(sheet.row_values(1))
doi_links = sheet.col_values(4)[1:]
print(doi_links)
# Out:
# ['Timestamp', 'Link', 'Original work or survey paper?', 'DOI number as clickable string', 'Year of Publication (all four digits)', 'Authors ', 'Field of Study of Primary Author', 'Algorithm included?', 'Title', 'Problem Attributes', 'Strategies', 'Notes']
# ['https://doi.org/10.1016/j.ins.2016.01.074', 'https://doi.org/10.1016/j.neucom.2015.04.084', 'https://doi.org/10.1016/j.aml.2007.01.006', 'None', 'https://doi.org/10.1145/321921.321925', 'https://doi.org/10.1162/089976699300016034 ', 'https://doi.org/10.1109/34.790431', 'https://doi.org/10.1016/S0167-8655(01)00017-4', 'https://doi.org/10.1109/34.6778', 'https://doi.org/10.1109/34.211474', 'https://doi.org/10.1109/ICPR.2000.906030', 'https://doi.org/10.1142/S0218001404003228', 'https://doi.org/10.1038/nbt1196', 'https://doi.org/10.1007/3-540-63223-9_124']

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup, Comment, NavigableString
import re
import time
import urllib
import string
import random

# %%
for i in range(len(doi_links)):
    if doi_links[i] != "None":
        try:
            print(doi_links[i])
            conn = urlopen(doi_links[i])
            html = conn.read()
            soup = BeautifulSoup(html, "html5lib")
            redirect = soup.find('input')['value']
            #print(redirect)
            print("\t",urllib.parse.unquote(redirect))
        except:
            print("\tFORBIDDEN")
            
    else:
        print(sheet.col_values(9)[i+1])
# Out:
# https://doi.org/10.1016/j.ins.2016.01.074
# 	 https://www.sciencedirect.com/science/article/pii/S002002551630010X?via%3Dihub
# https://doi.org/10.1016/j.neucom.2015.04.084
# 	 https://www.sciencedirect.com/science/article/pii/S0925231215006359?via%3Dihub
# https://doi.org/10.1016/j.aml.2007.01.006
# 	 https://www.sciencedirect.com/science/article/pii/S0893965907001012?via%3Dihub
# On random graphs I
# https://doi.org/10.1145/321921.321925
# FORBIDDEN
# https://doi.org/10.1162/089976699300016034
# 	 /action/cookieAbsent
# https://doi.org/10.1109/34.790431
# 	 loginModalWindow
# https://doi.org/10.1016/S0167-8655(01)00017-4
# 	 https://www.sciencedirect.com/science/article/pii/S0167865501000174?via%3Dihub
# https://doi.org/10.1109/34.6778
# 	 loginModalWindow
# https://doi.org/10.1109/34.211474
# 	 loginModalWindow
# https://doi.org/10.1109/ICPR.2000.906030
# 	 loginModalWindow
# https://doi.org/10.1142/S0218001404003228
# FORBIDDEN
# https://doi.org/10.1038/nbt1196
#
# ...

# %%
conn = urlopen(doi_links[0])
html = conn.read()
soup = BeautifulSoup(html, "html5lib")
redirect = soup.find('input')['value']
redirect = urllib.parse.unquote(redirect)

conn = urlopen(redirect)
html = conn.read()
soup = BeautifulSoup(html, "html5lib")
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html class="ie9" lang="en"><![endif]--><html lang="en"><head>
#       <meta content="S002002551630010X" name="citation_pii"/>
# <meta content="0020-0255" name="citation_issn"/>
# <meta content="346-347" name="citation_volume"/>
# <meta content="197" name="citation_lastpage"/>
# <meta content="Elsevier" name="citation_publisher"/>
# <meta content="180" name="citation_firstpage"/>
# <meta content="Information Sciences" name="citation_journal_title"/>
# <meta content="JOUR" name="citation_type"/>
# <meta content="10.1016/j.ins.2016.01.074" name="citation_doi"/>
# <meta content="10.1016/j.ins.2016.01.074" name="dc.identifier"/>
# <meta content="Full-length article" name="citation_article_type"/>
# <meta content="In this paper we survey methods for performing a comparative graph analysis and explain the history, foundations and differences of such techniques of…" property="og:description"/>
# ...

# %%
url = https://link.springer.com/content/pdf/10.1007%2Fs10044-008-0141-y.pdf""
